# %%
# countbyvalue is action which is used to count how many times the element is occured in the RDD
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName('count action')
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/sample_words.txt')

# %%
rdd.countByValue()
# Out:
# Out[3]: defaultdict(int,
#             {'this mongo company animal': 1,
#              'cat dog ant mic laptop': 1,
#              'chair switch mobile am charger cover': 1,
#              'amanda any alarm ant': 1})

# %%
rdd2 = rdd.flatMap(lambda x:x.split(' '))
rdd2.countByValue()
# Out:
# Out[5]: defaultdict(int,
#             {'this': 1,
#              'mongo': 1,
#              'company': 1,
#              'animal': 1,
#              'cat': 1,
#              'dog': 1,
#              'ant': 2,
#              'mic': 1,
#              'laptop': 1,
#              'chair': 1,
#              'switch': 1,
#              'mobile': 1,
#              'am': 1,
#              'charger': 1,
#              'cover': 1,
#              'amanda': 1,
#              'any': 1,
#              'alarm': 1})

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
