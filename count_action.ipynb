# %%
# count is action which is used to count the number of element from the RDD
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName('count action')
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/sample_words.txt')

# %%
rdd.collect()
# Out:
# Out[3]: ['this mongo company animal',
#  'cat dog ant mic laptop',
#  'chair switch mobile am charger cover',
#  'amanda any alarm ant']

# %%
rdd.count()
# Out:
# Out[4]: 4

# %%
rdd2 = rdd.flatMap(lambda x:x.split(' '))
rdd2.collect()
# Out:
# Out[6]: ['this',
#  'mongo',
#  'company',
#  'animal',
#  'cat',
#  'dog',
#  'ant',
#  'mic',
#  'laptop',
#  'chair',
#  'switch',
#  'mobile',
#  'am',
#  'charger',
#  'cover',
#  'amanda',
#  'any',
#  'alarm',
#  'ant']

# %%
rdd2.count()
# Out:
# Out[7]: 19

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
